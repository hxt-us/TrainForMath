# %%
# !git config --global --unset http.proxy
# !git config --global --unset https.proxy
# !git config --global http.sslVerify false
# !git clone https://github.com/hxt-us/TrainForMath.git
# %cd TrainForMath
# !pip install -r requirements.txt --quiet
# Out:
# Cloning into 'TrainForMath'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 14 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 876.95 KiB | 3.95 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /kaggle/working/TrainForMath
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.6 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# ...

# %%
# %cd /kaggle/working/TrainForMath
# Out:
# /kaggle/working/TrainForMath

# %%
from huggingface_hub import login
login("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")

# %%
# 'Viet-Mistral/Vistral-7B-Chat'
# 'berkeley-nest/Starling-LM-7B-alpha'
# 'deepseek-ai/deepseek-math-7b-rl'
# 'AI-MO/NuminaMath-7B-TIR'

# !accelerate launch finetune.py --base_model 'deepseek-ai/deepseek-math-7b-rl'\
--data_path "train.json" --test_path "test.json"\
--learning_rate 5e-5 --num_epochs 4 --eval_batch_size 1\
--lora_r 16 --lora_alpha 32 --lora_target_modules '[q_proj,v_proj]' --lora_dropout 0.05 \
--batch_size 4 --val_set_size 0.1 --cutoff_len 768 --micro_batch_size 2 --max_grad_norm 1\
--optim "adamw_torch" --warmup_ratio 0.05 --weight_decay 0.01\
--adam_beta1 0.9 --adam_beta2 0.95 --adam_epsilon 1e-5\
--output_dir './lora-alpaca-zalo'\
--train_qlora True\

# optim sẽ set = "paged_adamw_32bit", nếu train_qlora True
# lora_target_modules='[q_proj,k_proj,v_proj,o_proj]'

# --wandb_api_key "nếu xài"\
# --huggingface_token "nếu xài"\
# --huggingface_repo "nếu xài"
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...

# %%
import pandas as pd

pred_df = pd.read_csv('submission.csv')

true_df = pd.read_csv('answer.csv')

acc = (pred_df['answer'] == true_df['answer']).sum()/true_df.shape[0]
